# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

print("Understanding the Dataset....!\n")

file_name = "sales.csv"

if not os.path.exists(file_name):
    print("File not found....!")
    exit()
    
data = pd.read_csv(file_name)
print("Data Loaded Successfully....!")

df=pd.read_csv(file_name)
print("\nData stored successfully in dataframe....!")
print("Shape of the dataframe : ",df.shape)
print("\nColumns in the dataframe : ",df.columns)
print("\n First Five rows",df.head())
print("\n Last Five rows",df.tail())
print("\n Info of the dataframe : ",df.info())
print("\n Describe of the dataframe : ",df.describe())
print("\n Sum of null values : ",df.isnull().sum())

# with using Median
median_age=df['Age'].median()
df['Age']=df['Age'].fillna(median_age)
print("\n Median of Age : ",median_age)
median_spending=df['Spending'].median()
df['Spending']=df['Spending'].fillna(median_spending)
print("\n Median of Spending : ",median_spending)

#using mean
#FOR AGE:


mean_age=df['Age'].mean()
df['Age']=df['Age'].fillna(mean_age)
print("Means Age",mean_age)

#Distribution Analysis

plt.figure(figsize=(5,5))
df['Spending'].hist(bins=10,color='skyblue',edgecolor='black',linewidth=0.8)
plt.title("Distribution of Spending")
plt.xlabel("Spending Amount")
plt.ylabel("Number of Customers")
plt.show()

#correlation Matrix

correlation=df.corr(numeric_only=True)
print("\n correlation matrix :",correlation)

# PS C:\Users\Exam\Desktop\B1>.\venv\Scripts\activate.bat
  #20 Set-ExecutionPolicy -ExecutionPolicy Bypass -Scope Process
  #21 .\venv\Scripts\Activate.ps1
# Out:
# Understanding the Dataset....!
#
# Data Loaded Successfully....!
#
# Data stored successfully in dataframe....!
# Shape of the dataframe :  (50, 5)
#
# Columns in the dataframe :  Index(['Customer_ID', 'Age', 'City', 'Spending', 'Visits_Per_Month'], dtype='str')
#
#  First Five rows    Customer_ID   Age         City  Spending  Visits_Per_Month
# 0            1  25.0     New York     500.0                 2
# 1            2  30.0  Los Angeles     700.0                 4
# 2            3   NaN      Chicago     450.0                 3
# 3            4  45.0      Chicago    1500.0                10
# 4            5  30.0     New York       NaN                 5
#
#  Last Five rows     Customer_ID   Age         City  Spending  Visits_Per_Month
# 45           46  29.0     New York     620.0                 3
# 46           47  53.0  Los Angeles    1700.0                10
# 47           48   NaN      Houston     810.0                 4
# 48           49  27.0        Miami     530.0                 2
# 49           50  32.0      Chicago     740.0                 5
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_ID       50 non-null     int64
#  1   Age               45 non-null     float64
#  2   City              50 non-null     str
#  3   Spending          46 non-null     float64
#  4   Visits_Per_Month  50 non-null     int64
# dtypes: float64(2), int64(2), str(1)
# memory usage: 2.1 KB
#
#  Info of the dataframe :  None
#
#  Describe of the dataframe :         Customer_ID         Age     Spending  Visits_Per_Month
# count     50.00000   45.000000    46.000000         50.000000
# mean      25.50000   38.888889  1070.652174          4.800000
# std       14.57738   19.292276  1025.246642          2.539484
# min        1.00000   22.000000   300.000000          1.000000
# 25%       13.25000   29.000000   585.000000          3.000000
# 50%       25.50000   33.000000   815.000000          4.500000
# 75%       37.75000   44.000000  1187.500000          6.000000
# max       50.00000  120.000000  6000.000000         10.000000
#
#  Sum of null values :  Customer_ID         0
# Age                 5
# City                0
# Spending            4
# Visits_Per_Month    0
# dtype: int64
#
#  Median of Age :  33.0
#
#  Median of Spending :  815.0
# Means Age 38.3
#  correlation matrix :                   Customer_ID       Age  Spending  Visits_Per_Month
# Customer_ID          1.000000 -0.066118 -0.037338          0.148848
# Age                 -0.066118  1.000000  0.970541          0.117690
# Spending            -0.037338  0.970541  1.000000          0.033997
# Visits_Per_Month     0.148848  0.117690  0.033997          1.000000

# %%
print("Plotting Correlation Heatmap")
plt.figure(figsize=(7,4))
sns.heatmap(correlation,annot=True,cmap='coolwarm',fmt='.0f')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Plotting Correlation Heatmap

# %%
#outliers Detection
plt.figure(figsize=(7,4))
sns.boxplot(x=df['Age'],color='lightgreen')
plt.title("BoxPlot of customer Age")
plt.xlabel('Age')
plt.show()

# %%
print("Find Outliers in Age")
outliers=df[df['Age']>100]
print("Found Outliers(s):")
print(outliers)
# Out:
# Find Outliers in Age
# Found Outliers(s):
#     Customer_ID    Age      City  Spending  Visits_Per_Month
# 6             7  120.0  New York    5000.0                 1
# 27           28  115.0   Houston    6000.0                 1
